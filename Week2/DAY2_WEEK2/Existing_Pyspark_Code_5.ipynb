# %%
df = spark.read.csv("data.csv", header=True)

df = df.withColumn("salary", df.salary.cast("int"))

df = df.filter(df.salary > 5000)

df.write.mode("overwrite").parquet("output/")

# %% [markdown]
# ### What is happening? 1)Identify transformations 2)Identify actions

# %% [markdown]
# ### Everytime we need to follow the Strategy that is to 1)Identify source 2)Identify transformations 3)Identify output
